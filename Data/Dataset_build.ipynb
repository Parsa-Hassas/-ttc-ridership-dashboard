# %%
import pandas as pd

# %%
D:\Portfolio Projects\Public Transit Ridership\Dataset_build.ipynb
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2025_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2024_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2023_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2021_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2020_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2019_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2018_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2017_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2016_P1D.csv
D:\Portfolio Projects\Public Transit Ridership\en_climate_daily_ON_615S001_2015_P1D.csv

# %%
Dataset_build.ipynb
en_climate_daily_ON_615S001_2025_P1D.csv
en_climate_daily_ON_615S001_2024_P1D.csv
en_climate_daily_ON_615S001_2023_P1D.csv
en_climate_daily_ON_615S001_2021_P1D.csv
en_climate_daily_ON_615S001_2020_P1D.csv
en_climate_daily_ON_615S001_2019_P1D.csv
en_climate_daily_ON_615S001_2018_P1D.csv
en_climate_daily_ON_615S001_2017_P1D.csv
en_climate_daily_ON_615S001_2016_P1D.csv
en_climate_daily_ON_615S001_2015_P1D.csv

# %%
df_cl_2016 = pd.read_csv('en_climate_daily_ON_615S001_2025_P1D.csv')
df_cl_2016.head()
# Out:
#    Longitude (x)  Latitude (y)        Station Name Climate ID   Date/Time  \
# 0         -79.47         43.78  TORONTO NORTH YORK    615S001  2025-01-01
# 1         -79.47         43.78  TORONTO NORTH YORK    615S001  2025-01-02
# 2         -79.47         43.78  TORONTO NORTH YORK    615S001  2025-01-03
# 3         -79.47         43.78  TORONTO NORTH YORK    615S001  2025-01-04
# 4         -79.47         43.78  TORONTO NORTH YORK    615S001  2025-01-05
#
#    Year  Month  Day Data Quality  Max Temp (°C)  ...  Total Snow (cm)  \
# 0  2025      1    1            †            3.0  ...              0.0
# 1  2025      1    2            †            1.0  ...              0.0
# 2  2025      1    3          NaN            NaN  ...              NaN
# 3  2025      1    4            †           -2.5  ...              0.0
# 4  2025      1    5            †           -1.0  ...              0.0
#
#    Total Snow Flag  Total Precip (mm)  Total Precip Flag  Snow on Grnd (cm)  \
# ...

# %%
df_cl_2016.dtypes
# Out:
# Longitude (x)                float64
# Latitude (y)                 float64
# Station Name                  object
# Climate ID                    object
# Date/Time                     object
# Year                           int64
# Month                          int64
# Day                            int64
# Data Quality                  object
# Max Temp (°C)                float64
# Max Temp Flag                float64
# Min Temp (°C)                float64
# Min Temp Flag                float64
# Mean Temp (°C)               float64
# Mean Temp Flag               float64
# Heat Deg Days (°C)           float64
# Heat Deg Days Flag           float64
# Cool Deg Days (°C)           float64
# Cool Deg Days Flag           float64
# Total Rain (mm)              float64
# Total Rain Flag               object
# Total Snow (cm)              float64
# Total Snow Flag               object
# Total Precip (mm)            float64
# Total Precip Flag             object
# ...
